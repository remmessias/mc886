# %%
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.39671087997870125
# For n_clusters = 3 The average silhouette_score is : 0.4934390321065685
# For n_clusters = 4 The average silhouette_score is : 0.4001760096015442
# For n_clusters = 5 The average silhouette_score is : 0.31994897524905347
# For n_clusters = 6 The average silhouette_score is : 0.21896710916843878
