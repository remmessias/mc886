# %% [markdown]
# # Projeto 2 - Regressão e Classificação
#
# Aluno: André Soranzzo Mota RA: 166404
#
# Aluna: Rebecca Moreira Messias RA: 186416
#
# *Participação*: O trabalho foi feito em Pair Programming

# %% [markdown]
# ## Objetivos
#
# Este trabalho visa aplicar métodos de aprendizagem para resolver tarefas de classificação e regressão. Em cada tarefa, deve-se utilizar as métricas e métodos de aprendizagem apropriados.

# %% [markdown]
# ## Importação de bibliotecas
#
# As bibliotecas utilizadas neste projeto foram:
# - **numpy**: manipular arrays
# - **pandas**: manipular os dados
# - **matplotlib**: plotar os gráficos
# - **time**: cálculo do tempo de funções
# - **sklearn**: redução de dimensionalidade e normalização dos dados, importação de dados
# - **math**: cálculo de operações matemáticas
# - **mpl_toolkits**: plotar em três dimensões (3d)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn import datasets, svm, metrics
from mpl_toolkits.mplot3d import axes3d
from sklearn.utils import shuffle
from math import sqrt

# %% [markdown]
# ## Parte 1 - Regressão
#
# Considere que você é um goleiro em uma partida de futebol robótico na RoboCup Teen Size League. Seu oponente vai chutar
# uma bola contra você. Seu objetivo é prever a posição da bola para interceptá-la, ou seja, defender seu gol.
# goleiro, está em x = 0, y = 0. O trabalho consiste na implementação de uma regressão linear e polinomial para prever a trajetória da bola. São dados dois conjuntos de dados: kick1 e kick2. Eles representam duas trajetórias diferentes para a bola. Deve-se aprender o melhor modelo para ajustar os dados.

# %% [markdown]
# ### Importação dos dados

# %%
kick1 = pd.read_table('kick1.dat', delimiter=' ', names=['x', 'y','z'])
kick2 = pd.read_table('kick2.dat', delimiter=' ', names=['x', 'y','z'])

fig = plt.figure(figsize=(10, 7.5), dpi=100)

ax = plt.axes(projection="3d")
ax.scatter3D(kick1.x, kick1.y, kick1.z, c='#7000b5');
ax.scatter3D(kick2.x, kick2.y, kick2.z, c='#37faaf');

X_field,Y_field = np.meshgrid(np.linspace(-3,3,4), np.linspace(0,2,2))
Z_field = np.zeros(X_field.shape)
ax.plot([-1, -1, 1, 1], [0, 0.3, 0.3, 0], zdir='y', zs=0, c='g')
ax.plot_surface(X_field,Y_field,Z_field,shade=False, color='g', alpha=0.4)
ax.plot([-2.5 , -2.5, 2.5, 2.5], [0, 1, 1, 0], zdir ='z', zs=0, c='g')
ax.plot([-1, -1, 1, 1], [0, 0.05, 0.05, 0], zdir ='z', zs=0, c='g')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.set_xlim(-3, 3)
ax.set_ylim(0 ,2)
ax.set_zlim(0, 0.5)

ax.view_init(30, 90)

plt.show()

# %%
kick_data = []

X = kick1.x.values
Y = kick1.y.values
Z = kick1.z.values

kick_data.append({
    'X' : {
        'data' : X,
        'linear_model': {
            'theta' : {},
            'cost' : {}  
        },
        'polynomial_model': {
            'theta' : {},
            'cost' : {}  
        }
    },
    'Y' : {
        'data' : Y,
        'linear_model': {
            'theta' : {},
            'cost' : {}  
        },
        'polynomial_model': {
            'theta' : {},
            'cost' : {}  
        }
    },
    'Z' : {
        'data' : Z,
        'linear_model': {
            'theta' : {},
            'cost' : {}  
        },
        'polynomial_model': {
            'theta' : {},
            'cost' : {}  
        }
    },
})

X = kick2.x.values
Y = kick2.y.values
Z = kick2.z.values

kick_data.append({
    'X' : {
        'data' : X,
        'linear_model': {
            'theta' : {},
            'cost' : {}  
        },
        'polynomial_model': {
            'theta' : {},
            'cost' : {}  
        }
    },
    'Y' : {
        'data' : Y,
        'linear_model': {
            'theta' : {},
            'cost' : {}  
        },
        'polynomial_model': {
            'theta' : {},
            'cost' : {}  
        }
    },
    'Z' : {
        'data' : Z,
        'linear_model': {
            'theta' : {},
            'cost' : {}  
        },
        'polynomial_model': {
            'theta' : {},
            'cost' : {}  
        }
    },
})

# %% [markdown]
# ### Stochastic Gradient Descent
#
# Stochastic Gradient Descent, ou "descida gradiente estocástica", calcula o gradiente utilizando uma única amostra (diferente do Batch Gradient Descent, que veremos posteriormente). É um método iterativo para otimizar uma função objetivo com propriedades de suavidade adequadas, que substitui o gradiente real (calculado a partir de todo o conjunto de dados) por uma estimativa do mesmo, calculada a partir de um subconjunto de dados selecionado de maneira aleatória. Isso reduz a carga computacional, principalmente em problemas de alta dimensão, sendo este, portanto, um benefício do SGD, por ser computacionalmente mais rápido.

# %%
def stochasticGradientDescent(X_b, y, lr='opt', eta0=0.001, n_epochs=50, tol=0.0005):
    m = X_b.shape[0] 
    cost = []
    X_b = np.c_[np.ones((X_b.shape[0], 1)), X_b] 
    theta = np.zeros(X_b.shape[1])
    
    cost_func = 100000
    for epoch in range(n_epochs):
        if cost_func < tol:
            break

        for i in range(m):
            xi = X_b[i: i+1]
            yi = y[i: i+1]

            loss = xi[0].dot(theta) - yi
            gradients = xi.T.dot(loss)
            alpha = eta0
            theta = theta - alpha * gradients

        cost_func = (loss ** 2)/2
        cost.append(cost_func)

    return theta, cost

# %% [markdown]
# ### Batch Gradient Descent
#
# Batch Gradient Descent, ou "descida do gradiente em lote", calcula o gradiente usando todo o conjunto de dados. Isso é ótimo para variedades de erro convexas ou relativamente suaves. Nesse caso, avançamos um pouco diretamente em direção a uma solução ótima, local ou global. São necessárias menos iterações, em comparações com o SGD.
# Imagine que o BGD tem um ponto que representa a distribuição da entrada, e o modelo quer aprender a distribuição dessa entrada. Ao redor da distribuição de entrada está uma área sombreada que representa as distribuições de entrada de todos os minibatches possíveis que eu poderia amostrar. É comum assumir que as distribuições de entrada do minibatch estão próximas da distribuição de entrada verdadeira. O BGD, em todas as etapas, leva a rota mais íngreme para alcançar a distribuição de entrada verdadeira. SGD, por outro lado, escolhe um ponto aleatório dentro da área sombreada e segue a rota mais íngreme em direção a este ponto. A cada iteração, porém, ele escolhe um novo ponto. A média de todas essas etapas se aproximará da verdadeira distribuição de entrada.

# %%
def gradientDescent(X_b, y, lr='opt', eta0=0.005, n_epochs=50, tol=0.01):
    m = X_b.shape[0] 
    cost = []
    X_b = np.c_[np.ones((X_b.shape[0], 1)), X_b] 
    theta = np.zeros(X_b.shape[1])
    X_b, y = shuffle(X_b, y)
    cost_func = 100000
    for epoch in range(n_epochs):
        if cost_func < tol:
            break
    
        loss = X_b.dot(theta) - y
        gradients = X_b.T.dot(loss) / m
        alpha = eta0        
        theta = theta - alpha * gradients
      
        cost_func = (np.sum(loss) ** 2)/2
        cost.append(cost_func)
 
    return theta, cost

# %% [markdown]
# ### Algoritmo de Regressão Linear

# %%
t = np.linspace(1, 5, 20)
t = np.c_[t, t**2]
t
# Out:
# array([[ 1.        ,  1.        ],
#        [ 1.21052632,  1.46537396],
#        [ 1.42105263,  2.01939058],
#        [ 1.63157895,  2.66204986],
#        [ 1.84210526,  3.3933518 ],
#        [ 2.05263158,  4.2132964 ],
#        [ 2.26315789,  5.12188366],
#        [ 2.47368421,  6.11911357],
#        [ 2.68421053,  7.20498615],
#        [ 2.89473684,  8.37950139],
#        [ 3.10526316,  9.64265928],
#        [ 3.31578947, 10.99445983],
#        [ 3.52631579, 12.43490305],
#        [ 3.73684211, 13.96398892],
#        [ 3.94736842, 15.58171745],
#        [ 4.15789474, 17.28808864],
#        [ 4.36842105, 19.08310249],
#        [ 4.57894737, 20.966759  ],
#        [ 4.78947368, 22.93905817],
#        [ 5.        , 25.        ]])

# %% [markdown]
# #### Regressão Linear com Stochastic Gradient Descent

# %%
n_epochs = 10000
tol = 1e-6

for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    for dim in kick_data[i]:
        starter_time = time.time()
        x = t[:,0]
        y = kick_data[i][dim]['data']
        theta, cost = stochasticGradientDescent(x, y, eta0=0.005, lr='opt', n_epochs=n_epochs, tol=tol) 
        time_1 = time.time() - starter_time

        kick_data[i][dim]['linear_model']['theta']['SGD'] = theta
        kick_data[i][dim]['linear_model']['cost']['SGD'] = cost
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %% [markdown]
# #### Função de Custo com Stochastic Gradient Descent

# %%
for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    fig = plt.figure(figsize=(14, 2), dpi=80)
    j = 1
    for dim in kick_data[i]:
        num_iterations = len(kick_data[i][dim]['linear_model']['cost']['SGD'])
        ax = plt.subplot(1, 3, j)
        ax.plot(np.arange(0,num_iterations), kick_data[i][dim]['linear_model']['cost']['SGD'], "y.")
        ax.set_ylabel('custo')
        ax.set_xlabel('numero de iterações')
        ax.set_title(dim)
        j = j + 1
    plt.show()
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %% [markdown]
# #### Regressão Linear com Batch Gradient Descent

# %%
n_epochs = 100000
tol = 1e-6
for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    for dim in kick_data[i]:
        starter_time = time.time()
        x = t[:,0]
        y = kick_data[i][dim]['data']
        theta, cost = gradientDescent(x, y, eta0=0.005, lr='opt', n_epochs=n_epochs, tol=tol) 
        time_1 = time.time() - starter_time

        kick_data[i][dim]['linear_model']['theta']['GD'] = theta
        kick_data[i][dim]['linear_model']['cost']['GD'] = cost
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %% [markdown]
# #### Função de Custo com Batch Gradient Descent

# %%
for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    fig = plt.figure(figsize=(14, 2), dpi=80)
    j = 1
    for dim in kick_data[i]:
        num_iterations = len(kick_data[i][dim]['linear_model']['cost']['GD'])
        ax = plt.subplot(1, 3, j)
        ax.plot(np.arange(0,num_iterations), kick_data[i][dim]['linear_model']['cost']['GD'], "y.")
        ax.set_ylabel('custo')
        ax.set_xlabel('numero de iterações')
        ax.set_title(dim)
        j = j + 1
    plt.show()
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %% [markdown]
# ### Algoritmo de Regressão Polinomial

# %% [markdown]
# #### Regressão Polinomial com Stochastic Gradient Descent

# %%
n_epochs = 10000
tol = 1e-6

for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    for dim in kick_data[i]:
        x = t[:,0] if dim == 'Y' else t
        y = kick_data[i][dim]['data']    
        starter_time = time.time()
        theta, cost = stochasticGradientDescent(x, y, eta0=7.5e-4, lr='opt', n_epochs=n_epochs, tol=tol) 
        time_1 = time.time() - starter_time

        kick_data[i][dim]['polynomial_model']['theta']['SGD'] = theta
        kick_data[i][dim]['polynomial_model']['cost']['SGD'] = cost
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %% [markdown]
# #### Função de Custo com Stochastic Gradient Descent

# %%
# %matplotlib inline

t_line = np.linspace(1, 5, 20)
t_line = np.c_[t_line, t_line**2]
t_line = np.c_[np.ones((t_line.shape[0], 1)), t_line] 

for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    fig = plt.figure(figsize=(14, 2), dpi=80)
    j = 1
    
    X_pol = t_line.dot(kick_data[i]['X']['polynomial_model']['theta']['SGD'])
    Y_pol = t_line[:,:2].dot(kick_data[i]['Y']['polynomial_model']['theta']['SGD'])
    Z_pol = t_line.dot(kick_data[i]['Z']['polynomial_model']['theta']['SGD'])

    ax = plt.subplot(1, 3, 1)
    ax.plot(t_line[:,1],X_pol,'r')
    ax.plot(t_line[:,1], kick_data[i]['X']['data'],'b.')
    ax.set_xlabel('t')
    ax.set_title('X')
    
    ax = plt.subplot(1, 3, 2)
    ax.plot(t_line[:,1],Y_pol,'r')
    ax.plot(t_line[:,1], kick_data[i]['Y']['data'],'b.')
    ax.set_xlabel('t')
    ax.set_title('Y')
    
    ax = plt.subplot(1, 3, 3)
    ax.plot(t_line[:,1],Z_pol,'r')
    ax.plot(t_line[:,1], kick_data[i]['Z']['data'],'b.')
    ax.set_xlabel('t')
    ax.set_title('Z')
    plt.show()
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %%
for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    fig = plt.figure(figsize=(14, 2), dpi=80)
    j = 1
    for dim in kick_data[i]:
        num_iterations = len(kick_data[i][dim]['polynomial_model']['cost']['SGD'])
        ax = plt.subplot(1, 3, j)
        ax.plot(np.arange(0,num_iterations), kick_data[i][dim]['polynomial_model']['cost']['SGD'], "y.")
        ax.set_ylabel('custo')
        ax.set_xlabel('numero de iterações')
        ax.set_title(dim)
        j = j + 1
    plt.show()
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %%
fig = plt.figure(figsize=(8, 6), dpi=80)

ax = plt.axes(projection="3d")

ax.scatter3D(kick1.x, kick1.y, kick1.z, c='#10a9a9', label="1 - kick")

ax.plot(
    X_pol, 
    Y_pol, 
    Z_pol, 
    c='#10a9a9', 
    label='2 - SGD - polynomial reg.', 
    alpha=0.8
)

ax.legend()

# field
X_field,Y_field = np.meshgrid(np.linspace(-3,3,4), np.linspace(0,2,2))
Z_field = np.zeros(X_field.shape)
ax.plot([-1, -1, 1, 1], [0, 0.3, 0.3, 0], zdir='y', zs=0, c='g')
ax.plot_surface(X_field,Y_field,Z_field,shade=False, color='g', alpha=0.4)
ax.plot([-2.5 , -2.5, 2.5, 2.5], [0, 1, 1, 0], zdir ='z', zs=0, c='g')
ax.plot([-1, -1, 1, 1], [0, 0.05, 0.05, 0], zdir ='z', zs=0, c='g')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(30, 90)

plt.show()

# %%
fig = plt.figure(figsize=(8, 6), dpi=80)

ax = plt.axes(projection="3d")

ax.scatter3D(kick2.x, kick2.y, kick2.z, c='#0000fa', label="2 - kick")

ax.plot(
    X_pol, 
    Y_pol, 
    Z_pol, 
    c='#10a9a9', 
    label='2 - SGD - polynomial reg.', 
    alpha=0.8
)

ax.legend()

# field
X_field,Y_field = np.meshgrid(np.linspace(-3,3,4), np.linspace(0,2,2))
Z_field = np.zeros(X_field.shape)
ax.plot([-1, -1, 1, 1], [0, 0.3, 0.3, 0], zdir='y', zs=0, c='g')
ax.plot_surface(X_field,Y_field,Z_field,shade=False, color='g', alpha=0.4)
ax.plot([-2.5 , -2.5, 2.5, 2.5], [0, 1, 1, 0], zdir ='z', zs=0, c='g')
ax.plot([-1, -1, 1, 1], [0, 0.05, 0.05, 0], zdir ='z', zs=0, c='g')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(30, 90)

plt.show()

# %% [markdown]
# #### Regressão Polinomial com Batch Gradient Descent

# %%
n_epochs = 50000
tol = 1e-5
for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    for dim in kick_data[i]:
        x = t[:,0] if dim == 'Y' else t
        y = kick_data[i][dim]['data']
        starter_time = time.time()
        theta, cost = gradientDescent(x, y, eta0=5e-3, lr='opt', n_epochs=n_epochs, tol=tol) 
        time_1 = time.time() - starter_time

        kick_data[i][dim]['polynomial_model']['theta']['GD'] = theta
        kick_data[i][dim]['polynomial_model']['cost']['GD'] = cost
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %% [markdown]
# #### Função de Custo com Batch Gradient Descent

# %%
for i in range(2):
    print('Kick: ', i+1, ' | index: ', i)
    fig = plt.figure(figsize=(14, 2), dpi=80)
    j = 1
    for dim in kick_data[i]:
        num_iterations = len(kick_data[i][dim]['polynomial_model']['cost']['GD'])
        ax = plt.subplot(1, 3, j)
        ax.plot(np.arange(0,num_iterations), kick_data[i][dim]['polynomial_model']['cost']['GD'], "y.")
        ax.set_ylabel('custo')
        ax.set_xlabel('numero de iterações')
        ax.set_title(dim)
        j = j + 1
    plt.show()
# Out:
# Kick:  1  | index:  0
# Kick:  2  | index:  1

# %% [markdown]
# ### 2.3 Validação do Modelo

# %%
def predictModel(X, Y, theta):
    X = np.c_[np.ones((X.shape[0], 1)), X] 
    predict_values = X.dot(theta)
    return predict_values

def meanSquaredError(Y_predicted, Y):
    error = 0
    m = len(Y_predicted)
    for i in range(m):
        error += ((Y_predicted[i] - Y[i])**2)
    return error/m

# %%
t_line = np.arange(1,20,0.05)
t_line = np.c_[t_line, t_line**2]

Kick_Model = []

for i in range(2):
    Kick_Model.append({
        'X' : {
            'linear_model': {
                'SGD': predictModel(t_line[:,0], kick_data[i]['X']['data'], kick_data[i]['X']['linear_model']['theta']['SGD']), 
                'GD' : predictModel(t_line[:,0], kick_data[i]['X']['data'], kick_data[i]['X']['linear_model']['theta']['GD'])
            },
            'polynomial_model': {
                'SGD': predictModel(t_line, kick_data[i]['X']['data'], kick_data[i]['X']['polynomial_model']['theta']['SGD']), 
                'GD' : predictModel(t_line, kick_data[i]['X']['data'], kick_data[i]['X']['polynomial_model']['theta']['GD'])
            }
        },
        'Y' : {
            'linear_model': {
                'SGD': predictModel(t_line[:,0], kick_data[i]['Y']['data'], kick_data[i]['Y']['linear_model']['theta']['SGD']), 
                'GD' : predictModel(t_line[:,0], kick_data[i]['Y']['data'], kick_data[i]['Y']['linear_model']['theta']['GD'])
            },
            'polynomial_model': {
                'SGD': predictModel(t_line[:,0], kick_data[i]['Y']['data'], kick_data[i]['Y']['polynomial_model']['theta']['SGD']), 
                'GD' : predictModel(t_line[:,0], kick_data[i]['Y']['data'], kick_data[i]['Y']['polynomial_model']['theta']['GD'])
            }
        },
        'Z' : {
            'linear_model': {
                'SGD': predictModel(t_line[:,0], kick_data[i]['Z']['data'], kick_data[i]['Z']['linear_model']['theta']['SGD']), 
                'GD' : predictModel(t_line[:,0], kick_data[i]['Z']['data'], kick_data[i]['Z']['linear_model']['theta']['GD'])
            },
            'polynomial_model': {
                'SGD': predictModel(t_line, kick_data[i]['Z']['data'], kick_data[i]['Z']['polynomial_model']['theta']['SGD']), 
                'GD' : predictModel(t_line, kick_data[i]['Z']['data'], kick_data[i]['Z']['polynomial_model']['theta']['GD'])
            }
        }
    })

# %%
# %matplotlib inline

color_schema = [
    {
        'points' : '#a51134',
        'linear' : '#ff7f00',
        'polynomial' : '#eb184a'
    },
    {
        'points' : '#0000fa',
        'linear' : '#3348f2',
        'polynomial' : '#10a9a9'
    }
]

for i in range(2):
    fig = plt.figure(figsize=(8, 6), dpi=80)
    ax = plt.axes(projection="3d")
    
    ax.scatter3D(
        kick_data[i]['X']['data'], 
        kick_data[i]['Y']['data'], 
        kick_data[i]['Z']['data'],
        c=color_schema[i]['points'], 
        label="kick"
    )
    
    ax.plot3D(
        Kick_Model[i]['X']['linear_model']['SGD'], 
        Kick_Model[i]['Y']['linear_model']['SGD'], 
        Kick_Model[i]['Z']['linear_model']['SGD'], 
        c=color_schema[i]['linear'], 
        label='linear reg. - SGD', 
        alpha=0.8
    )
    ax.plot3D(
        Kick_Model[i]['X']['linear_model']['GD'], 
        Kick_Model[i]['Y']['linear_model']['GD'], 
        Kick_Model[i]['Z']['linear_model']['GD'], 
        '--',
        c=color_schema[i]['linear'], 
        label='linear reg. - GD', 
        alpha=0.7
    )
    
    ax.plot3D(
        Kick_Model[i]['X']['polynomial_model']['SGD'], 
        Kick_Model[i]['Y']['polynomial_model']['SGD'], 
        Kick_Model[i]['Z']['polynomial_model']['SGD'], 
        c=color_schema[i]['polynomial'], 
        label='polynomial reg. - SGD', 
        alpha=0.8
    )
    ax.plot3D(
        Kick_Model[i]['X']['polynomial_model']['GD'], 
        Kick_Model[i]['Y']['polynomial_model']['GD'], 
        Kick_Model[i]['Z']['polynomial_model']['GD'], 
        '--',
        c=color_schema[i]['polynomial'], 
        label='polynomial reg. - GD', 
        alpha=0.7
    )

    ax.legend()

    X_field,Y_field = np.meshgrid(np.linspace(-3,3,4), np.linspace(0,2,2))
    Z_field = np.zeros(X_field.shape)
    ax.plot([-1, -1, 1, 1], [0, 0.3, 0.3, 0], zdir='y', zs=0, c='g')
    ax.plot_surface(X_field,Y_field,Z_field,shade=False, color='g', alpha=0.4)
    ax.plot([-2.5 , -2.5, 2.5, 2.5], [0, 1, 1, 0], zdir ='z', zs=0, c='g')
    ax.plot([-1, -1, 1, 1], [0, 0.05, 0.05, 0], zdir ='z', zs=0, c='g')

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

    ax.set_xlim(-3, 3)
    ax.set_ylim(0 ,2)
    ax.set_zlim(0, 0.5)
    
    title = 'kick ' + str(i+1)
    ax.set_title(title)
    
    ax.view_init(30, 90)

    plt.show()

# %% [markdown]
# ### Conclusões
#
# O modelo de regressão mais adequado para o problema é o polinomial, pois é o único que nos dá uma parábola. Dado que no mundo real existe a força da gravidade, não poderíamos utilizar a regressão linear.
# Analisando os gráficos logo acima referentes às trajetórias dos chutes 1 e 2, podemos tirar algumas conclusões. No kick1, a regressão polinomial GD (Batch Gradient Descent) nos dá uma parábola no sentido contrário, como se a bola estivesse sendo puxada para o céu, sendo assim, inapropriado para o nosso problema. Já a regressão polinomial SGD (Stochastic Gradient Descent), tanto em kick1 e kick2, nos dá uma trajetória mais realista do que seria a trajetória de uma bola que é atraída pela força da gravidade. Portanto, o modelo estocástica é o mais apropiado para a resolução do problema.
#
# Para sabermos se o robô será capaz de defender a bola ou não, precisamos de algumas informações. Uma delas é a altura do gol.
# Considere que o gol possui 1 metro de altura (eixo z) e 2 metros de largura (eixo x). Considere que o robô está inicialmente na posição x=0, y=0 e z=0, e que ele consegue pular 1,5 metros de altura, e se mover até 0,5 metros para a direita ou para a esquerda. Tendo essas informações, conseguimos plotar os gráfico acima que nos auxiliam a visualizar se a bola entra ou não no gol. Em ambos os casos é possível visualizar que a bola entra no gol.

# %% [markdown]
# ## Parte 2 - Classificação
#
# Na segunda parte deve-se resolver uma tarefa de classificação usando métodos de aprendizagem supervisionada. Iremos empregar o conjunto de dados de reconhecimento de dígitos manuscritos com base na caneta. É um banco de imagens simples e conhecido para reconhecimento de imagens. Consiste em imagens em escala de cinza de 8 por 8 pixels divididas em 10 classes de dígitos. Uma descrição completa pode ser encontrada no link: archive.ics.uci.edu/ml/datasets/Pen-Based+Recognition+of+Handwritten+Digits.

# %%
digits = datasets.load_digits()

# %%
fig, ax_array = plt.subplots(20, 20)
axes = ax_array.flatten()
for i, ax in enumerate(axes):
    ax.imshow(digits.images[i], cmap='gray_r')
plt.setp(axes, xticks=[], yticks=[], frame_on=False)
plt.tight_layout(h_pad=0.5, w_pad=0.01)

# %% [markdown]
# Das informações acima e dos testes, podemos verificar que o dataset é um conjunto de matrizes 8x8, ou seja, com 64 atributos que vão de 0 a 16, sendo 0 o branco e 16 o preto na escala de cinza. Ele é composto de 1797 instâncias, que são imagens de números e todos apresentam uma label em digits.target, classificando esses desenhos em números de 0 a 9.

# %%
print(digits.images.shape)
print(digits.target.shape)
# Out:
# (1797, 8, 8)
# (1797,)

# %%
print(digits.images[0])
print(digits.target[0])
# Out:
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]
# 0

# %% [markdown]
# ### Preparação dos dados

# %% [markdown]
# Para a utilização nos modelos, não aplicamos nenhum processo de normalização ou padronização por não acharmos necessário. Apenas redimensionamos as matrizes para arrays de 1 dimensão, que serão as entradas dos modelos, e separamos o dado em treino e teste.

# %%
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))
print(data[0])

x_train, x_test, y_train, y_test = train_test_split(data, digits.target, test_size=0.1, shuffle=False)
# Out:
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]

# %% [markdown]
# ### Primeiro modelo - Multi-layer Perception Classifier

# %%
mlp = MLPClassifier(hidden_layer_sizes=(15,), activation='logistic', alpha=1e-4,
                    solver='sgd', tol=1e-4, random_state=1,
                    learning_rate_init=.1, verbose=True, max_iter=500)
mlp.fit(x_train,y_train)
predicted_mlp = mlp.predict(x_test)
# Out:
# Iteration 1, loss = 2.12990477
# Iteration 2, loss = 1.62348061
# Iteration 3, loss = 1.14378936
# Iteration 4, loss = 0.77698097
# Iteration 5, loss = 0.68559807
# Iteration 6, loss = 0.51877928
# Iteration 7, loss = 0.41941538
# Iteration 8, loss = 0.35022688
# Iteration 9, loss = 0.28971205
# Iteration 10, loss = 0.26914483
# Iteration 11, loss = 0.22182951
# Iteration 12, loss = 0.21275885
# Iteration 13, loss = 0.18225727
# Iteration 14, loss = 0.18647463
# Iteration 15, loss = 0.16984299
# Iteration 16, loss = 0.16086355
# Iteration 17, loss = 0.14467735
# Iteration 18, loss = 0.20131161
# Iteration 19, loss = 0.14977532
# Iteration 20, loss = 0.13778417
# Iteration 21, loss = 0.21389763
# Iteration 22, loss = 0.14745449
# Iteration 23, loss = 0.13836939
# Iteration 24, loss = 0.11424192
# Iteration 25, loss = 0.10269810
# Iteration 26, loss = 0.09871750
# Iteration 27, loss = 0.09684883
# Iteration 28, loss = 0.08662653
# Iteration 29, loss = 0.10459018
# Iteration 30, loss = 0.08883087
# Iteration 31, loss = 0.11649876
# Iteration 32, loss = 0.11487252
# Iteration 33, loss = 0.11571233
# Iteration 34, loss = 0.08753455
# Iteration 35, loss = 0.07911750
# Iteration 36, loss = 0.11525910
# Iteration 37, loss = 0.08677540
# Iteration 38, loss = 0.07536535
# Iteration 39, loss = 0.06856026
# Iteration 40, loss = 0.06414149
# Iteration 41, loss = 0.05720913
# Iteration 42, loss = 0.05718178
# Iteration 43, loss = 0.05500777
# Iteration 44, loss = 0.05138236
# Iteration 45, loss = 0.08919120
# Iteration 46, loss = 0.07861653
# Iteration 47, loss = 0.05930508
# Iteration 48, loss = 0.05362589
# Iteration 49, loss = 0.05689416
# Iteration 50, loss = 0.04826683
# Iteration 51, loss = 0.04492164
# Iteration 52, loss = 0.05383477
# Iteration 53, loss = 0.04419322
# Iteration 54, loss = 0.04185193
# Iteration 55, loss = 0.03964627
# Iteration 56, loss = 0.03877596
# Iteration 57, loss = 0.04076908
# Iteration 58, loss = 0.03822196
# Iteration 59, loss = 0.04007627
# Iteration 60, loss = 0.04056971
# Iteration 61, loss = 0.03715420
# Iteration 62, loss = 0.03635436
# Iteration 63, loss = 0.03867731
# Iteration 64, loss = 0.03416557
# Iteration 65, loss = 0.03390563
# Iteration 66, loss = 0.03339579
# Iteration 67, loss = 0.03620585
# Iteration 68, loss = 0.03373917
# Iteration 69, loss = 0.03273808
# Iteration 70, loss = 0.03199874
# Iteration 71, loss = 0.03089967
# Iteration 72, loss = 0.03096783
# Iteration 73, loss = 0.03099460
# Iteration 74, loss = 0.03010774
# Iteration 75, loss = 0.02934371
# Iteration 76, loss = 0.02887043
# Iteration 77, loss = 0.02873354
# Iteration 78, loss = 0.02913809
# Iteration 79, loss = 0.02867674
# Iteration 80, loss = 0.03251637
# Iteration 81, loss = 0.02928141
# Iteration 82, loss = 0.02753674
# Iteration 83, loss = 0.02717498
# Iteration 84, loss = 0.02701922
# Iteration 85, loss = 0.02696795
# Iteration 86, loss = 0.02702815
# Iteration 87, loss = 0.02640183
# Iteration 88, loss = 0.02604104
# Iteration 89, loss = 0.02569835
# Iteration 90, loss = 0.02536834
# Iteration 91, loss = 0.02502820
# Iteration 92, loss = 0.02471264
# Iteration 93, loss = 0.02457512
# Iteration 94, loss = 0.02452593
# Iteration 95, loss = 0.02478026
# Iteration 96, loss = 0.02458981
# Iteration 97, loss = 0.02429972
# Iteration 98, loss = 0.02359842
# Iteration 99, loss = 0.02334052
# Iteration 100, loss = 0.02336477
# Iteration 101, loss = 0.02289218
# Iteration 102, loss = 0.02322332
# Iteration 103, loss = 0.02302168
# Iteration 104, loss = 0.02282717
# Iteration 105, loss = 0.02228809
# Iteration 106, loss = 0.02210093
# Iteration 107, loss = 0.02216324
# Iteration 108, loss = 0.02186175
# Iteration 109, loss = 0.02211343
# Iteration 110, loss = 0.02177790
# Iteration 111, loss = 0.02241283
# Iteration 112, loss = 0.02171510
# Iteration 113, loss = 0.02222765
# Iteration 114, loss = 0.02135674
# Iteration 115, loss = 0.02107741
# Iteration 116, loss = 0.02072729
# Iteration 117, loss = 0.02044840
# Iteration 118, loss = 0.02026620
# Iteration 119, loss = 0.02019399
# Iteration 120, loss = 0.02004940
# Iteration 121, loss = 0.02003373
# Iteration 122, loss = 0.01983634
# Iteration 123, loss = 0.02018991
# Iteration 124, loss = 0.01989582
# Iteration 125, loss = 0.02011671
# Iteration 126, loss = 0.01985595
# Iteration 127, loss = 0.01953228
# Iteration 128, loss = 0.01924506
# Iteration 129, loss = 0.01929902
# Iteration 130, loss = 0.01916361
# Iteration 131, loss = 0.01882447
# Iteration 132, loss = 0.01874261
# Iteration 133, loss = 0.01872874
# Iteration 134, loss = 0.01892447
# Iteration 135, loss = 0.01866056
# Iteration 136, loss = 0.01915064
# Iteration 137, loss = 0.01873247
# Iteration 138, loss = 0.01822729
# Iteration 139, loss = 0.01815370
# Iteration 140, loss = 0.01833648
# Iteration 141, loss = 0.01788550
# Iteration 142, loss = 0.01772391
# Iteration 143, loss = 0.01759710
# Iteration 144, loss = 0.01770882
# Iteration 145, loss = 0.01745008
# Iteration 146, loss = 0.01735107
# Iteration 147, loss = 0.01752212
# Iteration 148, loss = 0.01779607
# Iteration 149, loss = 0.01723372
# Iteration 150, loss = 0.01708379
# Iteration 151, loss = 0.01697583
# Iteration 152, loss = 0.01687817
# Iteration 153, loss = 0.01673745
# Iteration 154, loss = 0.01674182
# Iteration 155, loss = 0.01700879
# Iteration 156, loss = 0.01657487
# Iteration 157, loss = 0.01662138
# Iteration 158, loss = 0.01649017
# Iteration 159, loss = 0.01636461
# Iteration 160, loss = 0.01625398
# Iteration 161, loss = 0.01632149
# Iteration 162, loss = 0.01642108
# Iteration 163, loss = 0.01624861
# Iteration 164, loss = 0.01603316
# Iteration 165, loss = 0.01596100
# Iteration 166, loss = 0.01591349
# Iteration 167, loss = 0.01586372
# Iteration 168, loss = 0.01571007
# Iteration 169, loss = 0.01556373
# Iteration 170, loss = 0.01547782
# Iteration 171, loss = 0.01559510
# Iteration 172, loss = 0.01537527
# Iteration 173, loss = 0.01531771
# Iteration 174, loss = 0.01552298
# Iteration 175, loss = 0.01527090
# Iteration 176, loss = 0.01535830
# Iteration 177, loss = 0.01512399
# Iteration 178, loss = 0.01503662
# Iteration 179, loss = 0.01498703
# Iteration 180, loss = 0.01498669
# Iteration 181, loss = 0.01486181
# Iteration 182, loss = 0.01480939
# Iteration 183, loss = 0.01469651
# Iteration 184, loss = 0.01460304
# Iteration 185, loss = 0.01460569
# Iteration 186, loss = 0.01445888
# Iteration 187, loss = 0.01450797
# Iteration 188, loss = 0.01450078
# Iteration 189, loss = 0.01437110
# Iteration 190, loss = 0.01442714
# Iteration 191, loss = 0.01425697
# Iteration 192, loss = 0.01413124
# Iteration 193, loss = 0.01414343
# Iteration 194, loss = 0.01406788
# Iteration 195, loss = 0.01423112
# Iteration 196, loss = 0.01399612
# Iteration 197, loss = 0.01390581
# Iteration 198, loss = 0.01383376
# Iteration 199, loss = 0.01381218
# Iteration 200, loss = 0.01394325
# Iteration 201, loss = 0.01418909
# Iteration 202, loss = 0.01370369
# Iteration 203, loss = 0.01368458
# Iteration 204, loss = 0.01356799
# Iteration 205, loss = 0.01347874
# Iteration 206, loss = 0.01344155
# Iteration 207, loss = 0.01336068
# Iteration 208, loss = 0.01335592
# Iteration 209, loss = 0.01328128
# Iteration 210, loss = 0.01318441
# Iteration 211, loss = 0.01318401
# Iteration 212, loss = 0.01313451
# Iteration 213, loss = 0.01314222
# Iteration 214, loss = 0.01306489
# Iteration 215, loss = 0.01296792
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
print(f"Classification report for classifier {mlp}:\n"
      f"{metrics.classification_report(y_test, predicted_mlp)}\n")
# Out:
# Classification report for classifier MLPClassifier(activation='logistic', hidden_layer_sizes=(15,),
#               learning_rate_init=0.1, max_iter=500, random_state=1,
#               solver='sgd', verbose=True):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.90      1.00      0.95        19
#            2       0.94      0.94      0.94        17
#            3       0.92      0.61      0.73        18
#            4       1.00      0.90      0.95        20
#            5       0.90      1.00      0.95        18
#            6       1.00      1.00      1.00        18
#            7       1.00      1.00      1.00        19
#            8       0.73      0.94      0.82        17
#            9       1.00      0.94      0.97        18
#
#     accuracy                           0.93       180
#    macro avg       0.94      0.93      0.93       180
# weighted avg       0.94      0.93      0.93       180

# %%
metrics.accuracy_score(y_test, predicted_mlp)
# Out:
# 0.9333333333333333

# %%
disp = metrics.plot_confusion_matrix(mlp, x_test, y_test)
disp.figure_.suptitle("Confusion Matrix")
plt.show()

# %% [markdown]
# ### Segundo modelo -  C-Support Vector Classification

# %%
svc = svm.SVC(gamma=0.001, C=100)
svc.fit(x_train, y_train)
predicted_svc = svc.predict(x_test)

# %% [markdown]
# Para apresentação dos resultados, apresentamos uma representação gráfica, seguida de métricas úteis para a comparação dos modelos.

# %%
_, axes = plt.subplots(nrows=1, ncols=6, figsize=(10, 3))
for ax, image, prediction in zip(axes, x_test, predicted_svc):
    ax.set_axis_off()
    image = image.reshape(8, 8)
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
    ax.set_title(f'Prediction: {prediction}')

# %%
print(f"Classification report for classifier {svc}:\n"
      f"{metrics.classification_report(y_test, predicted_svc)}\n")
# Out:
# Classification report for classifier SVC(C=100, gamma=0.001):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00        17
#            3       1.00      0.78      0.88        18
#            4       1.00      1.00      1.00        20
#            5       0.86      1.00      0.92        18
#            6       1.00      1.00      1.00        18
#            7       1.00      1.00      1.00        19
#            8       0.85      1.00      0.92        17
#            9       1.00      0.89      0.94        18
#
#     accuracy                           0.97       180
#    macro avg       0.97      0.97      0.97       180
# weighted avg       0.97      0.97      0.97       180

# %%
metrics.accuracy_score(y_test, predicted_svc)
# Out:
# 0.9666666666666667

# %%
disp = metrics.plot_confusion_matrix(svc, x_test, y_test)
disp.figure_.suptitle("Confusion Matrix")
plt.show()

# %% [markdown]
# ### Conclusões

# %% [markdown]
# O resultado do f1-score é satisfatório nos dois modelos já que os dois acima de 0.90 em uma escala de 0 a 1.0. O classificador SVC apresenta um score um pouco maior em aproximadamente 97% comparado aos 93% do MLP.
#
# Pela confusion matrix podemos obeservar alguns pontos:
# - Ambos os casos apresentaram problemas na classificação do dígito 3, sendo confundido pelo 5 ou 8 na predição. No MLP esse problema foi mais acentuado, errando 6 vezes essas comparações. O dígito 3 foi o pior em f1-score de ambos os casos: no MLP está em 0.73 e no SVC está calculado em 0.88.
# - O MLP apresentou um número geral de falsos positivos maior, observado por um score menor no precision, e um grande número de falsos negativos, obesrvado pelo recall baixo no dígito 3.
#
# Com essas análises podemos dizer que o SVC possui um taxa de acertos maior que o MLP.
